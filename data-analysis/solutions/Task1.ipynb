# %% [markdown]
# # Task 1 example solution

# %%
import os

cwd = os.getcwd()

# Import pandas library with alias pd
import pandas as pd

# Load up our dataset, due to solution file location we need to go one directory up
df = pd.read_csv('{}/../datasets/2014_us_cities.csv'.format(cwd))

# %%
# Look at the data
df
# Out:
#                                 name      pop        lat         lon
# 0                          New York   8287238  40.730599  -73.986581
# 1                       Los Angeles   3826423  34.053717 -118.242727
# 2                           Chicago   2705627  41.875555  -87.624421
# 3                           Houston   2129784  29.758938  -95.367697
# 4                      Philadelphia   1539313  39.952335  -75.163789
# 5                           Phoenix   1465114  33.446768 -112.075672
# 6                       San Antonio   1359174  29.424600  -98.495141
# 7                         San Diego   1321016  32.717421 -117.162771
# 8                            Dallas   1219399  32.776196  -96.796899
# 9                          San Jose    971495  37.343850 -121.883135
# 10                           Austin    839714  30.271129  -97.743700
# 11                     Jacksonville    829543  30.332184  -81.655651
# 12                    Indianapolis     827346  39.768333  -86.158350
# ...

# %% [markdown]
# ## Let us explore the data

# %%
df.head()
# Out:
#             name      pop        lat         lon
# 0      New York   8287238  40.730599  -73.986581
# 1   Los Angeles   3826423  34.053717 -118.242727
# 2       Chicago   2705627  41.875555  -87.624421
# 3       Houston   2129784  29.758938  -95.367697
# 4  Philadelphia   1539313  39.952335  -75.163789

# %%
df.tail()
# Out:
#                    name   pop        lat         lon
# 3223      Spanish Fort   7102  30.674913  -87.915272
# 3224        Plaquemine   7102  30.289083  -91.234274
# 3225  Milton-Freewater   7102  45.932635 -118.387743
# 3226            Benton   7096  36.034529  -88.101285
# 3227        Ocean City   7094  39.277616  -74.574600

# %%
df.mean()
# Out:
# pop    48874.270446
# lat       38.079047
# lon      -92.956938
# dtype: float64

# %%
df['pop'].median()
# Out:
# 18866.0

# %%
df.describe()
# Out:
#                 pop          lat          lon
# count  3.228000e+03  3228.000000  3228.000000
# mean   4.887427e+04    38.079047   -92.956938
# std    1.939184e+05     4.968243    15.293931
# min    7.094000e+03    24.833333  -124.263944
# 25%    1.106200e+04    34.141478   -99.787016
# 50%    1.886600e+04    38.777722   -88.934430
# 75%    4.103000e+04    41.586787   -81.461418
# max    8.287238e+06    49.100000   -68.011971

# %%
df.sort_values('pop', ascending=False)
# Out:
#                                 name      pop        lat         lon
# 0                          New York   8287238  40.730599  -73.986581
# 1                       Los Angeles   3826423  34.053717 -118.242727
# 2                           Chicago   2705627  41.875555  -87.624421
# 3                           Houston   2129784  29.758938  -95.367697
# 4                      Philadelphia   1539313  39.952335  -75.163789
# 5                           Phoenix   1465114  33.446768 -112.075672
# 6                       San Antonio   1359174  29.424600  -98.495141
# 7                         San Diego   1321016  32.717421 -117.162771
# 8                            Dallas   1219399  32.776196  -96.796899
# 9                          San Jose    971495  37.343850 -121.883135
# 10                           Austin    839714  30.271129  -97.743700
# 11                     Jacksonville    829543  30.332184  -81.655651
# 12                    Indianapolis     827346  39.768333  -86.158350
# ...

# %%
df.min()
# Out:
# name    Abilene
# pop         7094
# lat      24.8333
# lon     -124.264
# dtype: object

# %%
# Sort the data set by pop column in descending order and locate 0-index row fields name and pop
df.sort_values('pop', ascending=False).loc[0, ['name', 'pop']]
# Out:
# name    New York
# pop       8287238
# Name: 0, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 4 columns):
# name    3228 non-null object
# pop     3228 non-null int64
# lat     3228 non-null float64
# lon     3228 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 101.0+ KB

# %%
# Lets count the cites 
df[df['pop'] > 250000]['pop'].count()
# Out:
# 72

# %%
# Filter cities that starts with A and are at least 30 degrees north
df_filter = (df['name'].str.startswith('A')) & (df['lat'] >= 30)

# %%
df[df_filter]
# Out:
#                             name     pop        lat         lon
# 10                       Austin   839714  30.271129  -97.743700
# 31                  Albuquerque   551813  35.084103 -106.650985
# 39                      Atlanta   432135  33.749099  -84.390185
# 49                    Arlington   370908  32.735582  -97.107119
# 53                      Anaheim   340830  33.834752 -117.911732
# 104                       Akron   198909  41.083064  -81.518485
# 110                    Amarillo   193907  35.207219 -101.833825
# 200                       Allen   118878  37.888217  -95.317021
# 201                     Abilene   118727  32.446453  -99.733348
# 209                   Ann Arbor   115276  42.268157  -83.731229
# 229                      Arvada   107578  39.802764 -105.087484
# 245                     Antioch   103923  38.004921 -121.805789
# 267                      Albany    98012  42.651167  -73.754968
# 311                       Allen    87798  37.888217  -95.317021
# ...
